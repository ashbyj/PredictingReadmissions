# %% [markdown]
# # pre-processing

# %% [markdown]
# ## contents
# * [introduction](#introduction)
# * [dataframe prep](#prep)
# * [imports and load](#imports_and_load)
# * [categorical features](#categorical)
# * [numerical features](#numbers)
# * [train test split and export](#traintest)

# %% [markdown]
# ## introduction<a id='introduction'></a>

# %% [markdown]
# The purpose of this notebook is to prepare the data for modeling with these steps:
#
# - independence will be labeled and unnecessary variables removed
# - categorical features will be encoded
# - numerical features will be standardized
# - training and test data sets will be created and exported

# %% [markdown]
# ## imports and load<a id='imports_and_load'></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import warnings

warnings.filterwarnings('ignore')

admissions = pd.read_parquet('../data/interim/notebook2_output.parquet')
print(admissions.shape)
admissions.head()
# Out:
# (66224, 26)
#               patient_nbr             race  gender      age admission_type_id  \
# encounter_id
# 64410            86047875  AfricanAmerican  Female  [20-30)         emergency
# 28236            89869032  AfricanAmerican  Female  [40-50)         emergency
# 36900            77391171  AfricanAmerican    Male  [60-70)            urgent
# 62256            49726791  AfricanAmerican  Female  [60-70)          elective
# 73578            86328819  AfricanAmerican    Male  [60-70)         emergency
#
#              admission_source_id  time_in_hospital  num_lab_procedures  \
# encounter_id
# 64410             emergency room                 2                  11
# 28236             emergency room                 9                  47
# 36900                      Other                 7                  62
# 62256                      Other                 1                  49
# 73578             emergency room                12                  75
#
#               num_procedures  num_medications  ...  DischargedToCare  \
# encounter_id                                   ...
# 64410                      5         0.046863  ...             False
# 28236                      2         0.090064  ...             False
# 36900                      0         0.017615  ...             False
# 62256                      5        -0.521390  ...             False
# 73578                      5         0.046863  ...              True
#
#              outpatientTF emergencyTF inpatientTF one_lab_procedure  \
# encounter_id
# 64410                True       False        True             False
# 28236               False       False       False             False
# 36900               False       False       False             False
# 62256               False       False       False             False
# 73578               False       False       False             False
#
#               dx_cluster  Meglitinide_class  Sulfonylurea_class  \
# encounter_id
# 64410                  2                 No              Steady
# 28236                  3                 No                  No
# 36900                  2                 No                  Up
# 62256                  6                 No                  No
# 73578                  5                 No                  No
#
#               Thiazolidinedione_class  Alpha-glucosidase inhibitor_class
# encounter_id
# 64410                              No                                 No
# 28236                              No                                 No
# 36900                              No                                 No
# 62256                              No                                 No
# 73578                              No                                 No
#
# [5 rows x 26 columns]

# %%
pip list --format=freeze > requirements-nb3.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## dataframe prep<a id='prep'></a>

# %% [markdown]
# patient_nbr is also not needed, but more than one admission from a patient would not be considered independent which is needed for some models.  An additional feature indicating independence is needed.  This will have a value of 1 for 1 admission for a patient and a 0 for the rest.  An admission that resulted in a readmission will be given preference over one that did not.  After this, readmitBinary will be removed temporarily as they are the target variables. Readmitted will also be removed.

# %%
working_df = admissions.copy()
sort_order = ['<30 days', '>30 days']
working_df['readmitted'].cat.set_categories(sort_order, ordered=True, inplace=True)
working_df.sort_values(['patient_nbr', 'readmitted'], ascending=[True, False], inplace=True)

working_df['is_independent'] = working_df.groupby('patient_nbr').cumcount() == 0
working_df['is_independent'] = working_df['is_independent'].astype(bool)

target = working_df[['is_independent','readmitBinary']].copy()
working_df = working_df.drop(['patient_nbr','readmitted','readmitBinary'], axis=1)

working_df.head()
# Out:
#                          race  gender      age admission_type_id  \
# encounter_id
# 26264286            Caucasian  Female  [50-60)         emergency
# 14824206      AfricanAmerican  Female  [30-40)         emergency
# 8380170       AfricanAmerican  Female  [50-60)         emergency
# 30180318      AfricanAmerican  Female  [50-60)         emergency
# 55533660      AfricanAmerican  Female  [60-70)         emergency
#
#              admission_source_id  time_in_hospital  num_lab_procedures  \
# encounter_id
# 26264286          emergency room                 3                  31
# 14824206          emergency room                 5                  49
# 8380170           emergency room                 6                  43
# 30180318          emergency room                 6                  45
# 55533660          emergency room                10                  54
#
#               num_procedures  num_medications  number_diagnoses  ...  \
# encounter_id                                                     ...
# 26264286                   1         0.059233                 5  ...
# 14824206                   0        -0.155541                 3  ...
# 8380170                    2         0.046863                 2  ...
# 30180318                   4         0.070441                 6  ...
# 55533660                   2         0.106787                 9  ...
#
#              outpatientTF emergencyTF inpatientTF  one_lab_procedure  \
# encounter_id
# 26264286            False       False        True              False
# 14824206            False       False       False              False
# 8380170             False       False        True              False
# 30180318            False       False        True              False
# 55533660            False       False        True              False
#
#               dx_cluster  Meglitinide_class  Sulfonylurea_class  \
# encounter_id
# 26264286               2                 No              Steady
# 14824206               6                 No              Steady
# 8380170                5                 No                  No
# 30180318               8                 No                  No
# 55533660               0                 No                  No
#
#               Thiazolidinedione_class  Alpha-glucosidase inhibitor_class  \
# encounter_id
# 26264286                           No                                 No
# 14824206                           No                                 No
# 8380170                            No                                 No
# 30180318                           No                                 No
# 55533660                           No                                 No
#
#              is_independent
# encounter_id
# 26264286               True
# 14824206               True
# 8380170                True
# 30180318              False
# 55533660              False
#
# [5 rows x 24 columns]

# %% [markdown]
# encounter_id is also not needed, but serves as the index, so it will be left in place.

# %% [markdown]
# ## categorical features<a id='categorical'></a>

# %%
working_df.dtypes
# Out:
# race                                 category
# gender                               category
# age                                  category
# admission_type_id                    category
# admission_source_id                  category
# time_in_hospital                        int64
# num_lab_procedures                      int64
# num_procedures                          int64
# num_medications                       float64
# number_diagnoses                        int64
# metformin                            category
# insulin                              category
# glyburide-metformin                  category
# DischargedToCare                         bool
# outpatientTF                             bool
# emergencyTF                              bool
# inpatientTF                              bool
# one_lab_procedure                        bool
# dx_cluster                              int32
# Meglitinide_class                      object
# Sulfonylurea_class                     object
# Thiazolidinedione_class                object
# Alpha-glucosidase inhibitor_class      object
# is_independent                           bool
# dtype: object

# %% [markdown]
# The 4 *_class features at the bottom of this list are also categorical features and should be converted and 'Alpha-glucosidase inhibitor_class' should be renamed for conveinence.

# %%
working_df = working_df.rename(columns={'Alpha-glucosidase inhibitor_class': 'alpha_gluc_inhibitor_class'})

need_to_be_cat = ['alpha_gluc_inhibitor_class','Sulfonylurea_class','Thiazolidinedione_class','Meglitinide_class','dx_cluster']
working_df[need_to_be_cat] = working_df[need_to_be_cat].astype('category')
working_df.dtypes
# Out:
# race                          category
# gender                        category
# age                           category
# admission_type_id             category
# admission_source_id           category
# time_in_hospital                 int64
# num_lab_procedures               int64
# num_procedures                   int64
# num_medications                float64
# number_diagnoses                 int64
# metformin                     category
# insulin                       category
# glyburide-metformin           category
# DischargedToCare                  bool
# outpatientTF                      bool
# emergencyTF                       bool
# inpatientTF                       bool
# one_lab_procedure                 bool
# dx_cluster                    category
# Meglitinide_class             category
# Sulfonylurea_class            category
# Thiazolidinedione_class       category
# alpha_gluc_inhibitor_class    category
# is_independent                    bool
# dtype: object

# %% [markdown]
# Finally, the categorical variables will be one hot encoded.

# %%
working_df = pd.get_dummies(working_df, drop_first=True)

# %% [markdown]
# ## numerical features<a id='numbers'></a>

# %% [markdown]
# Now the numerical features can be scaled to a range of 0-1.

# %%
finite_vals = working_df.loc[working_df['num_medications'] != -np.inf, 'num_medications']
finite_vals = finite_vals.mean()
working_df['num_medications'] = working_df['num_medications'].replace([np.inf, -np.inf, np.nan], finite_vals)

number_columns = working_df.select_dtypes(include=['int64', 'float64']).columns.to_list()
scaler = MinMaxScaler()
working_df[number_columns] = scaler.fit_transform(working_df[number_columns])

# %% [markdown]
# The boolean features also need to be converted to numerics.

# %%
bools = working_df.select_dtypes(include=['bool']).columns.to_list()
working_df[bools] = working_df[bools].astype(int)

# %%
pd.set_option('display.max_rows', None)
print(working_df.dtypes)
pd.reset_option('display.max_rows')
# Out:
# time_in_hospital                      float64
# num_lab_procedures                    float64
# num_procedures                        float64
# num_medications                       float64
# number_diagnoses                      float64
# DischargedToCare                        int64
# outpatientTF                            int64
# emergencyTF                             int64
# inpatientTF                             int64
# one_lab_procedure                       int64
# is_independent                          int64
# race_Caucasian                          uint8
# gender_Male                             uint8
# age_[10-20)                             uint8
# age_[20-30)                             uint8
# age_[30-40)                             uint8
# age_[40-50)                             uint8
# age_[50-60)                             uint8
# age_[60-70)                             uint8
# age_[70-80)                             uint8
# age_[80-90)                             uint8
# age_[90-100)                            uint8
# admission_type_id_urgent                uint8
# admission_type_id_elective              uint8
# admission_type_id_Other                 uint8
# admission_source_id_Other               uint8
# admission_source_id_emergency room      uint8
# metformin_No                            uint8
# metformin_Steady                        uint8
# metformin_Up                            uint8
# insulin_No                              uint8
# insulin_Steady                          uint8
# insulin_Up                              uint8
# glyburide-metformin_No                  uint8
# glyburide-metformin_Steady              uint8
# glyburide-metformin_Up                  uint8
# dx_cluster_1                            uint8
# dx_cluster_2                            uint8
# dx_cluster_3                            uint8
# dx_cluster_4                            uint8
# dx_cluster_5                            uint8
# dx_cluster_6                            uint8
# dx_cluster_7                            uint8
# dx_cluster_8                            uint8
# Meglitinide_class_No                    uint8
# Meglitinide_class_Steady                uint8
# Meglitinide_class_Up                    uint8
# Sulfonylurea_class_No                   uint8
# Sulfonylurea_class_Steady               uint8
# Sulfonylurea_class_Up                   uint8
# Thiazolidinedione_class_No              uint8
# Thiazolidinedione_class_Steady          uint8
# Thiazolidinedione_class_Up              uint8
# alpha_gluc_inhibitor_class_No           uint8
# alpha_gluc_inhibitor_class_Steady       uint8
# alpha_gluc_inhibitor_class_Up           uint8
# dtype: object

# %% [markdown]
# ## train test split and export<a id='traintest'></a>

# %%
X_train, X_test, y_train, y_test = train_test_split(
    working_df,
    target,
    test_size=0.2, 
    random_state=42,
    stratify=target['readmitBinary']
)

# %%
shapes = {
    'X_train': X_train.shape,
    'X_test': X_test.shape,
    'y_train': y_train.shape,
    'y_test': y_test.shape
}

shapes
# Out:
# {'X_train': (52979, 56),
#  'X_test': (13245, 56),
#  'y_train': (52979, 2),
#  'y_test': (13245, 2)}

# %%
X_train.to_parquet(path='../data/interim/X_train.parquet')
X_test.to_parquet(path='../data/interim/X_test.parquet')
y_train.to_parquet(path='../data/interim/y_train.parquet')
y_test.to_parquet(path='../data/interim/y_test.parquet')
